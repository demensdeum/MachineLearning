# %%
# %run main.py
# Out:
# Textgenrnn quotes text generator by demensdeum 2018 (demensdeum@gmail.com)
# train/generate? train
# dataset filename? (dataset_quotes_ru.txt)
# Endless train mode, every 4 epochs will be saved. CTRL+C to exit
# 89 texts collected.
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 7,694 character sequences.
# Epoch 1/4
# 60/60 [==============================] - 20s 329ms/step - loss: 3.3902
# ####################
# Temperature: 0.2
# ####################
#      т        на   а а      тт     ее   т  е а  о       а     о       е   ан и     с   и о он нн и   еатаа т атеа  н оино т  т ана      аа а о т         но   а  и   т т  т     т а    оааа  он           оее        н      т    то о   о  ае    о т ее  а ант  аи т нота  н  тн а   т          н а  е
#
# ...
